# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('/Volumes/workspace/default/csv/retail_sales_dataset.csv')
df.head()

# %%
df= spark.table("retail_sales_dataset")
rs = df.toPandas()

# %% [markdown]
# Understanding the date

# %%
rs.info

# %%
rs.describe()
#rs.isnull().sum()
#rs['Date'] = pd.to_datetime(rs['Date'])

# %%
rs.columns

# %%
rs.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)
rs.head(2)

# %%
display(rs)
#dispaly the entire table.

# %%
print(rs)
#shows a synopsis of the table

# %%
rs.head()
#SHOWS 1ST 5 ROWA

# %%
rs.tail()
#SHOWS LAST 5 ROWS

# %%
rs.duplicated().sum()

# %%
rs.shape

# %%
rs.nunique()

# %%
rs = rs.dropna()

# %%
rs = rs.fillna(0)

# %%
rs.dtypes

# %%
rs['Date'] = pd.to_datetime(rs['Date'])

# %%
rs.dtypes

# %%
date_column = rs['Date']
date_column.dt.month
date_column.dt.day
date_column.dt.year
rs['Date'] = rs['Date'].dt.strftime('%Y-%m-%d')
rs

# %%
date_column=pd.DatetimeIndex(rs['Date'])
rs['Year']=date_column.year
rs['Month']=date_column.month
rs['Day']=date_column.day

# %%
display(rs)
#rs['Date'] = pd.to_datetime(rs['Date'])
#rs.dtypes
#rs['Date'] = rs['Date'].dt.strftime('%Y-%m-%d')
#rs.dtypes

# %%
rs.groupby('Month').Total_Amount.sum()

# %%
rs.groupby('Month')['Total_Amount'].sum().hist()

# %%
rs.groupby('Month')['Total_Amount'].sum().plot.bar()

# %%
# Sales by Category (Matplotlib)
sales_by_category = rs.groupby('Product_Category')['Total_Amount'].sum()
plt.figure()
sales_by_category.plot(kind='bar')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Sales Trend Over Time
#df['Date'] = pd.to_datetime(df['Date'])
sales_trend = rs.groupby('Date')['Total_Amount'].sum()
plt.figure(figsize=(10, 6))
sales_trend.plot(color = 'green')
plt.xticks(rotation=45, ha='right')
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Seaborn - Sales by Region
plt.figure()
sns.barplot(data=rs, x='Month', y='Total_Amount')
plt.title('Sales by Month')
plt.show()

# %%
plt.figure()
plt.hist(rs['Total_Amount'], bins=10)
plt.title('Distribution of Sales Amount')
plt.xlabel('Total Amount')
plt.ylabel('Frequency')
plt.show()

# %%
sales_by_category = rs.groupby('Product_Category')['Total_Amount'].sum()

plt.figure()
sales_by_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Contribution by Category')
plt.ylabel('')
plt.show()

# %%
sales_trend = rs.groupby('Date')['Total_Amount'].sum()

plt.figure(figsize=(10, 6))
#plt.xticks(rotation=45, ha='right')
plt.plot(sales_trend, marker='o')
plt.title('Sales Trend with Markers')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()
